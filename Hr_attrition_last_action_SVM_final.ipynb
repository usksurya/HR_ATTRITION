# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler

# %%
df=pd.read_csv("/content/Dataset - HR Employee Attrition yogesh.csv")

# %%
df
# Out:
#       EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0                  1       Yes   41      Travel_Rarely       1102
# 1                  2        No   49  Travel_Frequently        279
# 2                  3       Yes   37      Travel_Rarely       1373
# 3                  4        No   33  Travel_Frequently       1392
# 4                  5        No   27      Travel_Rarely        591
# ...              ...       ...  ...                ...        ...
# 2935            2936        No   36  Travel_Frequently        884
# 2936            2937        No   39      Travel_Rarely        613
# 2937            2938        No   27      Travel_Rarely        155
# 2938            2939        No   49  Travel_Frequently       1023
# 2939            2940        No   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
df.shape
# Out:
# (2940, 35)

# %%
#showing first five rows
df.head()
# Out:
#    EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0               1       Yes   41      Travel_Rarely       1102
# 1               2        No   49  Travel_Frequently        279
# 2               3       Yes   37      Travel_Rarely       1373
# 3               4        No   33  Travel_Frequently       1392
# 4               5        No   27      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                         1            80
# ...

# %%
#last five rows
df.tail()
# Out:
#       EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 2935            2936        No   36  Travel_Frequently        884
# 2936            2937        No   39      Travel_Rarely        613
# 2937            2938        No   27      Travel_Rarely        155
# 2938            2939        No   49  Travel_Frequently       1023
# 2939            2940        No   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 2935  Research & Development                23          2        Medical
# 2936  Research & Development                 6          1        Medical
# 2937  Research & Development                 4          3  Life Sciences
# 2938                   Sales                 2          3        Medical
# 2939  Research & Development                 8          3        Medical
#
#       EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
#finding out the missing value
df.isna().sum()
# Out:
# EmployeeNumber              0
# Attrition                   0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.shape
# Out:
# (2940, 35)

# %%
df
# Out:
#       EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0                  1       Yes   41      Travel_Rarely       1102
# 1                  2        No   49  Travel_Frequently        279
# 2                  3       Yes   37      Travel_Rarely       1373
# 3                  4        No   33  Travel_Frequently       1392
# 4                  5        No   27      Travel_Rarely        591
# ...              ...       ...  ...                ...        ...
# 2935            2936        No   36  Travel_Frequently        884
# 2936            2937        No   39      Travel_Rarely        613
# 2937            2938        No   27      Travel_Rarely        155
# 2938            2939        No   49  Travel_Frequently       1023
# 2939            2940        No   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
df=pd.get_dummies(df).astype(int)

# %%
df
# Out:
#       EmployeeNumber  Age  DailyRate  DistanceFromHome  Education  \
# 0                  1   41       1102                 1          2
# 1                  2   49        279                 8          1
# 2                  3   37       1373                 2          2
# 3                  4   33       1392                 3          4
# 4                  5   27        591                 2          1
# ...              ...  ...        ...               ...        ...
# 2935            2936   36        884                23          2
# 2936            2937   39        613                 6          1
# 2937            2938   27        155                 4          3
# 2938            2939   49       1023                 2          3
# 2939            2940   34        628                 8          3
#
#       EmployeeCount  EnvironmentSatisfaction  HourlyRate  JobInvolvement  \
# 0                 1                        2          94               3
# ...

# %%
df.shape
# Out:
# (2940, 57)

# %%
#label encoding
df=pd.read_csv("/content/Dataset - HR Employee Attrition yogesh.csv")

# %%
df.head()
# Out:
#    EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0               1       Yes   41      Travel_Rarely       1102
# 1               2        No   49  Travel_Frequently        279
# 2               3       Yes   37      Travel_Rarely       1373
# 3               4        No   33  Travel_Frequently       1392
# 4               5        No   27      Travel_Rarely        591
#
#                Department  DistanceFromHome  Education EducationField  \
# 0                   Sales                 1          2  Life Sciences
# 1  Research & Development                 8          1  Life Sciences
# 2  Research & Development                 2          2          Other
# 3  Research & Development                 3          4  Life Sciences
# 4  Research & Development                 2          1        Medical
#
#    EmployeeCount  ...  RelationshipSatisfaction StandardHours  \
# 0              1  ...                         1            80
# ...

# %%
#df.Attrition.unique()

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
#df['Attrition']=le.fit_transform(df['Attrition'])

# %%
df
# Out:
#       EmployeeNumber Attrition  Age     BusinessTravel  DailyRate  \
# 0                  1       Yes   41      Travel_Rarely       1102
# 1                  2        No   49  Travel_Frequently        279
# 2                  3       Yes   37      Travel_Rarely       1373
# 3                  4        No   33  Travel_Frequently       1392
# 4                  5        No   27      Travel_Rarely        591
# ...              ...       ...  ...                ...        ...
# 2935            2936        No   36  Travel_Frequently        884
# 2936            2937        No   39      Travel_Rarely        613
# 2937            2938        No   27      Travel_Rarely        155
# 2938            2939        No   49  Travel_Frequently       1023
# 2939            2940        No   34      Travel_Rarely        628
#
#                   Department  DistanceFromHome  Education EducationField  \
# 0                      Sales                 1          2  Life Sciences
# ...

# %%
df.Attrition.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.JobRole.unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df.BusinessTravel.unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df.Department.unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df.EducationField.unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
#df.Gender.unique()

# %%
df.MaritalStatus.unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
df.Over18.unique()
# Out:
# array(['Y'], dtype=object)

# %%
df.OverTime.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['BusinessTravel']=le.fit_transform(df['BusinessTravel'])

# %%
df['Department']=le.fit_transform(df['Department'])

# %%
df['EducationField']=le.fit_transform(df['EducationField'])

# %%
#df['Gender']=le.fit_transform(df['Gender'])

# %%
df['JobRole']=le.fit_transform(df['JobRole'])

# %%
df['MaritalStatus']=le.fit_transform(df['MaritalStatus'])

# %%
df['Over18']=le.fit_transform(df['Over18'])

# %%
df['OverTime']=le.fit_transform(df['OverTime'])

# %%
df
# Out:
#       EmployeeNumber Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0                  1       Yes   41               2       1102           2
# 1                  2        No   49               1        279           1
# 2                  3       Yes   37               2       1373           1
# 3                  4        No   33               1       1392           1
# 4                  5        No   27               2        591           1
# ...              ...       ...  ...             ...        ...         ...
# 2935            2936        No   36               1        884           1
# 2936            2937        No   39               2        613           1
# 2937            2938        No   27               2        155           1
# 2938            2939        No   49               1       1023           2
# 2939            2940        No   34               2        628           1
#
# ...

# %%
df.isna().sum()
# Out:
# EmployeeNumber              0
# Attrition                   0
# Age                         0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
df.describe().T
# Out:
#                            count          mean          std     min      25%  \
# EmployeeNumber            2940.0   1470.500000   848.849221     1.0   735.75
# Age                       2940.0     36.923810     9.133819    18.0    30.00
# BusinessTravel            2940.0      1.607483     0.665342     0.0     1.00
# DailyRate                 2940.0    802.485714   403.440447   102.0   465.00
# Department                2940.0      1.260544     0.527703     0.0     1.00
# DistanceFromHome          2940.0      9.192517     8.105485     1.0     2.00
# Education                 2940.0      2.912925     1.023991     1.0     2.00
# EducationField            2940.0      2.247619     1.331143     0.0     1.00
# EmployeeCount             2940.0      1.000000     0.000000     1.0     1.00
# EnvironmentSatisfaction   2940.0      2.721769     1.092896     1.0     2.00
# HourlyRate                2940.0     65.891156    20.325969    30.0    48.00
# ...

# %%
#Normalization and display the result
columns_to_normalize = [
     'DailyRate', 'Education', 'MonthlyIncome'
    , 'NumCompaniesWorked', 'PercentSalaryHike', 'TotalWorkingYears'
    , 'TrainingTimesLastYear', 'YearsAtCompany', 'YearsInCurrentRole'
    , 'YearsWithCurrManager'
]
# Removed extra spaces and comma
scaler = MinMaxScaler()
df[columns_to_normalize] = scaler.fit_transform(df[columns_to_normalize])

df.head()
# Out:
#    EmployeeNumber Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0               1       Yes   41               2   0.715820           2
# 1               2        No   49               1   0.126700           1
# 2               3       Yes   37               2   0.909807           1
# 3               4        No   33               1   0.923407           1
# 4               5        No   27               2   0.350036           1
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1       0.25               1              1  ...
# 1                 8       0.00               1              1  ...
# 2                 2       0.25               4              1  ...
# 3                 3       0.75               1              1  ...
# 4                 2       0.00               3              1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# ...

# %%
pd.DataFrame(df).describe()
# Out:
#        EmployeeNumber          Age  BusinessTravel    DailyRate   Department  \
# count     2940.000000  2940.000000     2940.000000  2940.000000  2940.000000
# mean      1470.500000    36.923810        1.607483     0.501421     1.260544
# std        848.849221     9.133819        0.665342     0.288791     0.527703
# min          1.000000    18.000000        0.000000     0.000000     0.000000
# 25%        735.750000    30.000000        1.000000     0.259843     1.000000
# 50%       1470.500000    36.000000        2.000000     0.501074     1.000000
# 75%       2205.250000    43.000000        2.000000     0.755190     2.000000
# max       2940.000000    60.000000        2.000000     1.000000     2.000000
#
#        DistanceFromHome    Education  EducationField  EmployeeCount  \
# count       2940.000000  2940.000000     2940.000000         2940.0
# mean           9.192517     0.478231        2.247619            1.0
# std            8.105485     0.255998        1.331143            0.0
# ...

# %% [markdown]
# DATA visualization

# %%
df.head()
# Out:
#    EmployeeNumber Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0               1       Yes   41               2   0.715820           2
# 1               2        No   49               1   0.126700           1
# 2               3       Yes   37               2   0.909807           1
# 3               4        No   33               1   0.923407           1
# 4               5        No   27               2   0.350036           1
#
#    DistanceFromHome  Education  EducationField  EmployeeCount  ...  \
# 0                 1       0.25               1              1  ...
# 1                 8       0.00               1              1  ...
# 2                 2       0.25               4              1  ...
# 3                 3       0.75               1              1  ...
# 4                 2       0.00               3              1  ...
#
#    RelationshipSatisfaction StandardHours  StockOptionLevel  \
# 0                         1            80                 0
# ...

# %%
df.Age.unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60])

# %%
#males are denotes by 1 and females are denoted by 0

# %% [markdown]
# Bar chart

# %%
sns.countplot(x = 'Attrition', hue= 'Gender', data = df)
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %% [markdown]
# males seem to hold the edge over which sex was layed off amongst the 2940 employees

# %%
sns.barplot(x='Age', data=df, y='MonthlyIncome')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %% [markdown]
# people who are older and supposedly having more experience tend to earn more than their younger counterparts but the the number of younger workers is significantly higher than the older members of the industry as well

# %%
plt.bar(df['OverTime'],df['JobSatisfaction'],color = 'purple', edgecolor = 'orange', linewidth = 0.1)
plt.title('Relation between OverTime and JobSatisfaction')
plt.xlabel('JobSatisfaction')
plt.ylabel('OverTime')

plt.show()

# %% [markdown]
# Histogram

# %%
plt.hist(df['Age'],color = 'indigo', edgecolor = 'aqua', linewidth = 0.6)
plt.title('Histogram of Age')

plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# majority of the workforce was made up of people in their mid 30s and early 40s

# %%
plt.hist(df['OverTime'],color = 'grey', edgecolor = 'orange', linewidth = 0.6)
plt.title('Histogram of OverTime')
plt.xlabel('OverTime')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# the frequency of overtime working is less hence it seems like a rare ocurrence to have a large group of people working over time

# %%
plt.hist(df['Attrition'], color = 'green')
plt.title('Histogram of Attrition')
plt.xlabel('Attrition')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# the amount of people layed of is lesser in ratio compared to the overal strenght of the workforce

# %% [markdown]
# LINE PLOT

# %%
sns.lineplot(x = 'DistanceFromHome', y = 'OverTime', data = df)
# Out:
# <Axes: xlabel='DistanceFromHome', ylabel='OverTime'>

# %% [markdown]
# employees commting from far away places seem to rarely take up the overtime role in the company

# %%
sns.lineplot(x = 'DistanceFromHome', y = 'Attrition', data = df)
# Out:
# <Axes: xlabel='DistanceFromHome', ylabel='Attrition'>

# %% [markdown]
# the graph does not offer any conclusive evidence about the lay off pattern and distance form home but a significant amount of people seemed to have been layed off who commute between 23-26 kms away. 12-14 and 21-23 are tied after

# %%
import seaborn as sns

# %%
sns.lineplot(x = 'Age', y = 'MonthlyIncome', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %% [markdown]
# monthly income of older employees is higher than younger employees and almost follows a linear pattern.hence hikes in salary is reflective of either work experience outside the company or years spent in service for the company

# %%
sns.lineplot(x = 'Age', y = 'JobSatisfaction', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='JobSatisfaction'>

# %% [markdown]
# job satisfication seems to hold a median level amonsgt all age groups but the older employees edge the others in this aspect probably due to a more salary package or just they just seem to enjoy the stage in their late years

# %%
sns.lineplot(x = 'Age', y = 'Attrition', data = df)
# Out:
# <Axes: xlabel='Age', ylabel='Attrition'>

# %% [markdown]
# a significant amount of people layed seems to constitute the younger workforce compared to older employees but the majority group which are the middle aged employees seem to have not experienced much change in personell

# %%
#dependency on Attition based on Gender
sns.scatterplot(y = 'Age', x = 'Attrition', data = df , hue = 'Gender')
# Out:
# <Axes: xlabel='Attrition', ylabel='Age'>

# %% [markdown]
# Barplot

# %%
#boxplot
sns.boxplot(x = 'Age', data = df)
# Out:
# <Axes: xlabel='Age'>

# %% [markdown]
# 50% of workforc is between the ages of 30 and 44 and the upper 3rd quartile seems to have the bigger chunk compared to 1st quartile

# %%
#countplot
sns.countplot(x= 'Gender', data = df, hue = 'MonthlyIncome')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# males are denoted as 1 and females are denoted as 0 and the male population seems to have more high earners compared to their female counterparts

# %%
df
# Out:
#       EmployeeNumber Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0                  1       Yes   41               2   0.715820           2
# 1                  2        No   49               1   0.126700           1
# 2                  3       Yes   37               2   0.909807           1
# 3                  4        No   33               1   0.923407           1
# 4                  5        No   27               2   0.350036           1
# ...              ...       ...  ...             ...        ...         ...
# 2935            2936        No   36               1   0.559771           1
# 2936            2937        No   39               2   0.365784           1
# 2937            2938        No   27               2   0.037938           1
# 2938            2939        No   49               1   0.659270           2
# 2939            2940        No   34               2   0.376521           1
#
# ...

# %%
sns.countplot(x= 'Gender', data = df, hue = 'Attrition')
# Out:
# <Axes: xlabel='Gender', ylabel='count'>

# %% [markdown]
# Bivariate graphs

# %%
#jointplot
sns.jointplot(x= 'Age', y = 'YearsSinceLastPromotion',data = df, kind = 'kde', color = 'purple')

# %% [markdown]
# middle aged category seemed to have experienced a more stagnant career progression and have been due for a promotion for longer time than other groups

# %%
#jointplot
sns.jointplot(x =  'Age', y = 'YearsSinceLastPromotion',data = df, kind = 'hex', color = 'purple')

# %%
sns.jointplot(x = 'TotalWorkingYears', y = 'MonthlyIncome', data = df, kind = 'scatter', color = 'green')

# %%
sns.jointplot(x = 'TotalWorkingYears', y = 'MonthlyIncome', data = df, kind = 'hist', color = 'cyan')

# %% [markdown]
# Monthly income of employees seems to vary linearly for the majority with the total working years spent in the company and majaority of employees seems to make up the younger quartile of the total strength.

# %%
sns.countplot(x= 'Attrition', data = df, hue = 'Education')
# Out:
# <Axes: xlabel='Attrition', ylabel='count'>

# %% [markdown]
# the lower the education the higher number of employees among that category got layed off

# %%
df
# Out:
#       EmployeeNumber Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0                  1       Yes   41               2   0.715820           2
# 1                  2        No   49               1   0.126700           1
# 2                  3       Yes   37               2   0.909807           1
# 3                  4        No   33               1   0.923407           1
# 4                  5        No   27               2   0.350036           1
# ...              ...       ...  ...             ...        ...         ...
# 2935            2936        No   36               1   0.559771           1
# 2936            2937        No   39               2   0.365784           1
# 2937            2938        No   27               2   0.037938           1
# 2938            2939        No   49               1   0.659270           2
# 2939            2940        No   34               2   0.376521           1
#
# ...

# %%
sns.jointplot(x= 'TotalWorkingYears', y = 'YearsAtCompany', data = df, kind = 'scatter', color = 'purple' )

# %% [markdown]
# A significant amount of employees seem to be recruited from other companies and do not qualify as freshers so the workforce in general seems to be well experienced.there appears to be a linear progression in terms of recruitment strategies from the companies end who have made it a point to maintain experince and youth

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2940 entries, 0 to 2939
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            2940 non-null   int64
#  1   Attrition                 2940 non-null   object
#  2   Age                       2940 non-null   int64
#  3   BusinessTravel            2940 non-null   int64
#  4   DailyRate                 2940 non-null   float64
#  5   Department                2940 non-null   int64
#  6   DistanceFromHome          2940 non-null   int64
#  7   Education                 2940 non-null   float64
#  8   EducationField            2940 non-null   int64
#  9   EmployeeCount             2940 non-null   int64
#  10  EnvironmentSatisfaction   2940 non-null   int64
#  11  Gender                    2940 non-null   object
#  12  HourlyRate                2940 non-null   int64
#  13  JobInvolvement            2940 non-null   int64
# ...

# %%
for i in df:
  plt.figure(figsize=(25,15),facecolor='white', edgecolor = 'yellow', linewidth = 0.4)
  sns.boxplot(y=i,data=df, color = 'cyan')
  plt.show()

# %%
#converting categorical datat to numerical data for heat map analysis

# %%
df.Attrition.unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.Gender.unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()

# %%
df['Attrition']=le.fit_transform(df['Attrition'])

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %% [markdown]
# Heat map representation

# %%
plt.figure(figsize=(20,16))
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
plt.figure(figsize=(28,16))
sns.heatmap(df.corr(),cmap = 'coolwarm',annot = True)
# Out:
# <Axes: >

# %% [markdown]
# *   hike in salary seems to favour one's performance rating
# *  joblevel and  total working years directly affects monthly income
#
# *   joblevel seems to increase with total working years
# *   years under the same manager seems to delay once promotion
#
#
# *   different departments have their clutches around coveted jobroles and some departments will lead to a more prominent role than others
#
#
# *   stockoption level decreases with married individuals

# %% [markdown]
# Building the Model

# %%
# preparing model considering all the variables
import statsmodels.formula.api as smf # for regression model

ml1 = smf.ols('Attrition ~  Age +	BusinessTravel+DailyRate+	Department+	DistanceFromHome+	Education+	EducationField+	EmployeeCount+	EnvironmentSatisfaction+	Gender+	HourlyRate+	JobInvolvement+	JobLevel+	JobRole	+JobSatisfaction	+MaritalStatus+	MonthlyIncome+	MonthlyRate+	NumCompaniesWorked+	Over18+	OverTime+	PercentSalaryHike+	PerformanceRating+	RelationshipSatisfaction+	StandardHours+	StockOptionLevel+	TotalWorkingYears+	TrainingTimesLastYear+	WorkLifeBalance+	YearsAtCompany+	YearsInCurrentRole+	YearsSinceLastPromotion+	YearsWithCurrManager', data = df).fit() # regression model

# Summary
ml1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              Attrition   R-squared:                       0.215
# Model:                            OLS   Adj. R-squared:                  0.207
# Method:                 Least Squares   F-statistic:                     26.51
# Date:                Thu, 04 Jul 2024   Prob (F-statistic):          2.30e-129
# Time:                        08:42:29   Log-Likelihood:                -875.27
# No. Observations:                2940   AIC:                             1813.
# Df Residuals:                    2909   BIC:                             1998.
# Df Model:                          30
# Covariance Type:            nonrobust
# ...
#                                coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------------
# ...

# %%
#identify and mitigate multicollinearity
from statsmodels.stats.outliers_influence import variance_inflation_factor

# Calculate VIF for each feature
X = df.drop('Attrition', axis=1)  # Drop the target variable
vif_data = pd.DataFrame()
vif_data['Feature'] = X.columns
vif_data['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]

print(vif_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: divide by zero encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# /usr/local/lib/python3.10/dist-packages/statsmodels/regression/linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
#                      Feature        VIF
# 0             EmployeeNumber   1.005566
# 1                        Age   2.054189
# 2             BusinessTravel   1.016513
# 3                  DailyRate   1.024596
# 4                 Department   1.942153
# 5           DistanceFromHome   1.017372
# 6                  Education   1.063961
# 7             EducationField   1.016237
# 8              EmployeeCount   0.000000
# 9    EnvironmentSatisfaction   1.017638
# 10                    Gender   1.019538
# 11                HourlyRate   1.021343
# 12            JobInvolvement   1.020812
# ...

# %%
df.corr()
# Out:
#                           EmployeeNumber  Attrition       Age  BusinessTravel  \
# EmployeeNumber                  1.000000  -0.005184 -0.005175       -0.007905
# Attrition                      -0.005184   1.000000 -0.159205        0.000074
# Age                            -0.005175  -0.159205  1.000000        0.024751
# BusinessTravel                 -0.007905   0.000074  0.024751        1.000000
# DailyRate                      -0.025742  -0.056652  0.010661       -0.004086
# Department                     -0.005183   0.063991 -0.031882       -0.009044
# DistanceFromHome                0.016464   0.077924 -0.001686       -0.024469
# Education                       0.020950  -0.031373  0.208034        0.000757
# EducationField                 -0.001229   0.026846 -0.040873        0.023724
# EmployeeCount                        NaN        NaN       NaN             NaN
# EnvironmentSatisfaction         0.008712  -0.103369  0.010146        0.004174
# ...

# %%
df.describe()
# Out:
#        EmployeeNumber    Attrition          Age  BusinessTravel    DailyRate  \
# count     2940.000000  2940.000000  2940.000000     2940.000000  2940.000000
# mean      1470.500000     0.161224    36.923810        1.607483     0.501421
# std        848.849221     0.367800     9.133819        0.665342     0.288791
# min          1.000000     0.000000    18.000000        0.000000     0.000000
# 25%        735.750000     0.000000    30.000000        1.000000     0.259843
# 50%       1470.500000     0.000000    36.000000        2.000000     0.501074
# 75%       2205.250000     0.000000    43.000000        2.000000     0.755190
# max       2940.000000     1.000000    60.000000        2.000000     1.000000
#
#         Department  DistanceFromHome    Education  EducationField  \
# count  2940.000000       2940.000000  2940.000000     2940.000000
# mean      1.260544          9.192517     0.478231        2.247619
# std       0.527703          8.105485     0.255998        1.331143
# ...

# %%
#resolving scaling issue with normalalization
from sklearn.preprocessing import MinMaxScaler
norm=MinMaxScaler()
df_norm=norm.fit_transform(df)
pd.DataFrame(df)
# Out:
#       EmployeeNumber  Attrition  Age  BusinessTravel  DailyRate  Department  \
# 0                  1          1   41               2   0.715820           2
# 1                  2          0   49               1   0.126700           1
# 2                  3          1   37               2   0.909807           1
# 3                  4          0   33               1   0.923407           1
# 4                  5          0   27               2   0.350036           1
# ...              ...        ...  ...             ...        ...         ...
# 2935            2936          0   36               1   0.559771           1
# 2936            2937          0   39               2   0.365784           1
# 2937            2938          0   27               2   0.037938           1
# 2938            2939          0   49               1   0.659270           2
# 2939            2940          0   34               2   0.376521           1
#
# ...

# %%
df_norm
# Out:
# array([[0.00000000e+00, 1.00000000e+00, 5.47619048e-01, ...,
#         2.22222222e-01, 0.00000000e+00, 2.94117647e-01],
#        [3.40251786e-04, 0.00000000e+00, 7.38095238e-01, ...,
#         3.88888889e-01, 6.66666667e-02, 4.11764706e-01],
#        [6.80503573e-04, 1.00000000e+00, 4.52380952e-01, ...,
#         0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        ...,
#        [9.99319496e-01, 0.00000000e+00, 2.14285714e-01, ...,
#         1.11111111e-01, 0.00000000e+00, 1.76470588e-01],
#        [9.99659748e-01, 0.00000000e+00, 7.38095238e-01, ...,
#         3.33333333e-01, 0.00000000e+00, 4.70588235e-01],
#        [1.00000000e+00, 0.00000000e+00, 3.80952381e-01, ...,
#         1.66666667e-01, 6.66666667e-02, 1.17647059e-01]])

# %%
pd.DataFrame(df_norm).describe()
# Out:
#                 0            1            2            3            4   \
# count  2940.000000  2940.000000  2940.000000  2940.000000  2940.000000
# mean      0.500000     0.161224     0.450567     0.803741     0.501421
# std       0.288822     0.367800     0.217472     0.332671     0.288791
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       0.250000     0.000000     0.285714     0.500000     0.259843
# 50%       0.500000     0.000000     0.428571     1.000000     0.501074
# 75%       0.750000     0.000000     0.595238     1.000000     0.755190
# max       1.000000     1.000000     1.000000     1.000000     1.000000
#
#                 5            6            7            8       9   ...  \
# count  2940.000000  2940.000000  2940.000000  2940.000000  2940.0  ...
# mean      0.630272     0.292590     0.478231     0.449524     0.0  ...
# std       0.263851     0.289482     0.255998     0.266229     0.0  ...
# ...

# %%
from sklearn.svm import SVC
from sklearn.model_selection import train_test_split

# %%
# splitting data into train and test
train,test = train_test_split(df, test_size = 0.20)

# %%
print(df.shape)
print(train.shape)
print(test.shape)
# Out:
# (2940, 35)
# (2352, 35)
# (588, 35)

# %%
train = pd.DataFrame(train)
test = pd.DataFrame(test)
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2352 entries, 364 to 1062
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   EmployeeNumber            2352 non-null   int64
#  1   Attrition                 2352 non-null   int64
#  2   Age                       2352 non-null   int64
#  3   BusinessTravel            2352 non-null   int64
#  4   DailyRate                 2352 non-null   float64
#  5   Department                2352 non-null   int64
#  6   DistanceFromHome          2352 non-null   int64
#  7   Education                 2352 non-null   float64
#  8   EducationField            2352 non-null   int64
#  9   EmployeeCount             2352 non-null   int64
#  10  EnvironmentSatisfaction   2352 non-null   int64
#  11  Gender                    2352 non-null   int64
#  12  HourlyRate                2352 non-null   int64
#  13  JobInvolvement            2352 non-null   int64
# ...

# %%
df.drop(['EmployeeCount','Over18','StandardHours'],axis=1,inplace=True)

# %%
# segregating the input and output variable from train and test
train_X = train.iloc[:, 2:]
train_y = train.iloc[:, 1]
test_X  = test.iloc[:, 2:]
test_y  = test.iloc[:, 1]

# %%
train_X
# Out:
#       Age  BusinessTravel  DailyRate  Department  DistanceFromHome  Education  \
# 364    37               2   0.586256           1                10       0.50
# 2417   52               2   0.664281           2                 5       0.50
# 1221   45               0   0.813171           1                 1       0.00
# 2564   40               2   0.887616           2                 9       0.25
# 2714   30               1   0.866142           1                 2       0.75
# ...   ...             ...        ...         ...               ...        ...
# 2808   30               2   0.603436           2                 9       0.50
# 350    42               2   0.316392           0                 2       0.00
# 2223   39               1   0.603436           1                22       0.50
# 2873   39               2   0.012169           2                15       0.75
# 1062   44               1   0.780959           1                 2       0.00
#
# ...

# %%
train_y
# Out:
# 364     0
# 2417    1
# 1221    0
# 2564    0
# 2714    0
#        ..
# 2808    1
# 350     0
# 2223    0
# 2873    0
# 1062    0
# Name: Attrition, Length: 2352, dtype: int64

# %%
df.shape
# Out:
# (2940, 32)

# %%
# kernel = linear
model_linear = SVC(kernel = "linear")
model_linear.fit(train_X, train_y)
pred_test_linear = model_linear.predict(test_X)

res_linear=np.mean(pred_test_linear == test_y)

# %%
pd.crosstab(pred_test_linear,test_y)
# Out:
# Attrition    0   1
# row_0
# 0          478  90
# 1            8  12

# %%
# kernel = rbf
model_rbf = SVC(kernel = "rbf")
model_rbf.fit(train_X, train_y)
pred_test_rbf = model_rbf.predict(test_X)
res_rbf=np.mean(pred_test_rbf==test_y)

# %%
# kernel = polynomial
model_poly = SVC(kernel = "poly")
model_poly.fit(train_X, train_y)
pred_test_poly= model_poly.predict(test_X)

res_poly=np.mean(pred_test_poly==test_y)

# %%
# kernel = sigmoid
model_sigmoid = SVC(kernel = "sigmoid")
model_sigmoid.fit(train_X, train_y)
pred_test_sigmoid = model_sigmoid.predict(test_X)

res_sigmoid=np.mean(pred_test_sigmoid==test_y)

# %%
#pd.DataFrame({'Model':['Linear','RBF','Polynomial','Sigmoid'],'Accuracy':[res_linear,res_rbf,]})
results_df = pd.DataFrame({'Model':['Linear','RBF','Polynomial','Sigmoid'],
              'Accuracy':[res_linear,res_rbf, res_poly, res_sigmoid]})

# %%
#print the accuracy results of different kernels
print("Accuracy results for different kernels:")
print(results_df)
# Out:
# Accuracy results for different kernels:
#         Model  Accuracy
# 0      Linear  0.833333
# 1         RBF  0.826531
# 2  Polynomial  0.826531
# 3     Sigmoid  0.763605

# %%
#choose the best model
best_model = results_df.loc[results_df['Accuracy'].idxmax()]
print("\nBest kernel:")
print(best_model)
# Out:
# Best kernel:
# Model         Linear
# Accuracy    0.833333
# Name: 0, dtype: object
